# %%
cd ../runs

# %%
# !wget http://opendata.atlas.cern/release/samples/MC/mc_105986.ZZ.root

# %%
ls

# %%
# !./CLA.sh mc_105986.ZZ.root ATLASOD -i ex1.adl -e 10000
